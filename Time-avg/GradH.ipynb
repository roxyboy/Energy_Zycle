# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:34305")
client
# Out:
# <Client: 'tcp://127.0.0.1:34305' processes=8 threads=40, memory=157.36 GiB>

# %%
import numpy as np
import xarray as xr
import pandas as pd
import os.path as op
from fastjmd95 import drhods, drhodt 
import os
import gsw
from xhistogram.xarray import histogram as xhist
from xgcm.grid import Grid
from xmitgcm import open_mdsdataset
from fastjmd95 import rho as densjmd95
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ddir = '/tank/chaocean/qjamet/RUNS/ORAR/reruns2/'
gdir = '/tank/chaocean/grid_chaO/gridMIT_update1/'
chaos = '/tank/chaocean/tuchida/'
savedir = '/tank/spectre/tuchida/chaocean/Snap/'

# %%
grav = 9.81
nensembs = 5
Kh = 20.
K4 = 1e10
Kr = 1e-5
thetaMax = 1e20
rhoConst = 9.998e2
# Cp = 3.994e3
Cp = 3989.244953
# years = np.arange(2008,2013,dtype=int)
ySstart = -15
yNstart = 15
yend = 50
dnf = 2160
nfile = 73

xchunk = 100
ychunk = 100

nmembs = np.arange(100,148)

# %%
years = np.arange(1967,1968,dtype=int)
ntimes = np.arange(1419120,1576800,dnf).reshape(len(years),nfile)
dd = 0  # 
yystart = 0
ntimes[yystart,dd:]
# Out:
# array([1419120, 1421280, 1423440, 1425600, 1427760, 1429920, 1432080,
#        1434240, 1436400, 1438560, 1440720, 1442880, 1445040, 1447200,
#        1449360, 1451520, 1453680, 1455840, 1458000, 1460160, 1462320,
#        1464480, 1466640, 1468800, 1470960, 1473120, 1475280, 1477440,
#        1479600, 1481760, 1483920, 1486080, 1488240, 1490400, 1492560,
#        1494720, 1496880, 1499040, 1501200, 1503360, 1505520, 1507680,
#        1509840, 1512000, 1514160, 1516320, 1518480, 1520640, 1522800,
#        1524960, 1527120, 1529280, 1531440, 1533600, 1535760, 1537920,
#        1540080, 1542240, 1544400, 1546560, 1548720, 1550880, 1553040,
#        1555200, 1557360, 1559520, 1561680, 1563840, 1566000, 1568160,
#        1570320, 1572480, 1574640])

# %%
dsg = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                              % (100)), 
                      grid_dir=gdir,
                      prefix=['snap_diagOcn'], delta_t=2e2,
                      iters=ntimes[0,0], 
                     ).isel(time=0).chunk({'YC':ychunk,'YG':ychunk,
                                           'XC':xchunk,'XG':xchunk})
grid = Grid(dsg, periodic=['X'])
Vol = (dsg.rA * dsg.drF * dsg.hFacC).where(dsg.maskC!=0.).reset_coords(drop=True)
dsg
# Out:
# <xarray.Dataset>
# Dimensions:  (XC: 1000, YC: 900, XG: 1000, YG: 900, Z: 46, Zp1: 47, Zu: 46,
#               Zl: 46)
# Coordinates: (12/33)
#     iter     int64 1419120
#     time     timedelta64[ns] 3285 days
#   * XC       (XC) >f4 262.0 262.1 262.2 262.3 262.3 ... 347.7 347.8 347.9 348.0
#   * YC       (YC) >f4 -19.92 -19.83 -19.75 -19.67 ... 54.75 54.83 54.92 55.0
#   * XG       (XG) >f4 262.0 262.0 262.1 262.2 262.3 ... 347.7 347.8 347.8 347.9
#   * YG       (YG) >f4 -19.96 -19.87 -19.79 -19.71 ... 54.71 54.79 54.88 54.96
#     ...       ...
#     maskW    (Z, YC, XG) bool dask.array<chunksize=(46, 100, 100), meta=np.ndarray>
#     maskS    (Z, YG, XC) bool dask.array<chunksize=(46, 100, 100), meta=np.ndarray>
#     maskInC  (YC, XC) bool dask.array<chunksize=(100, 100), meta=np.ndarray>
#     rhoRef   (Z) >f4 dask.array<chunksize=(46,), meta=np.ndarray>
#     maskInW  (YC, XG) bool dask.array<chunksize=(100, 100), meta=np.ndarray>
#     maskInS  (YG, XC) bool dask.array<chunksize=(100, 100), meta=np.ndarray>
# Data variables:
#     THETA    (Z, YC, XC) >f4 dask.array<chunksize=(46, 100, 100), meta=np.ndarray>
#     SALT     (Z, YC, XC) >f4 dask.array<chunksize=(46, 100, 100), meta=np.ndarray>
#     UVEL     (Z, YC, XG) >f4 dask.array<chunksize=(46, 100, 100), meta=np.ndarray>
#     VVEL     (Z, YG, XC) >f4 dask.array<chunksize=(46, 100, 100), meta=np.ndarray>
#     WVEL     (Zl, YC, XC) >f4 dask.array<chunksize=(46, 100, 100), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     title:        netCDF wrapper of MITgcm MDS binary data
#     source:       MITgcm
#     history:      Created by calling `open_mdsdataset(grid_dir='/tank/chaocea...

# %%
nmemb = 100
for itime in ntimes[yystart,:]:
    
    if itime == ntimes[yystart,0]:
        ds = open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                     % (nmemb)), 
                             grid_dir=gdir,
                             prefix=['snap_diagOcn'], delta_t=2e2,
                             iters=itime, 
                            ).chunk({'YC':ychunk,'YG':ychunk,
                                     'XC':xchunk,'XG':xchunk})
    else:
        ds = xr.concat([ds, open_mdsdataset(op.join(ddir,'memb%03d/run1967/ocn/' 
                                                    % (nmemb)), 
                                            grid_dir=gdir,
                                            prefix=['snap_diagOcn'], delta_t=2e2,
                                            iters=itime, 
                                           ).chunk({'YC':ychunk,'YG':ychunk,
                                                    'XC':xchunk,'XG':xchunk})
                       ], dim='time')

dsm = ds.reset_coords(drop=True).mean('time').compute().chunk({'YC':ychunk,'XC':xchunk})
grid = Grid(dsm, periodic=['X'])
    
pres = np.abs(grav*dsm.Z)
    
Ht = xr.ones_like(dsm.THETA.reset_coords(drop=True)) * np.nan
Hs = xr.ones_like(dsm.SALT.reset_coords(drop=True)) * np.nan
for kk in range(len(ds.Z)):
    alpha = xr.apply_ufunc(drhodt, 
                           (dsm.SALT.isel(Z=kk) 
                            * xr.ones_like(pres.isel(Z=slice(None,kk+1)))), 
                           (dsm.THETA.isel(Z=kk) 
                            * xr.ones_like(pres.isel(Z=slice(None,kk+1)))), 
                            pres.isel(Z=slice(None,kk+1)),
                            dask='parallelized')
    beta  = xr.apply_ufunc(drhods, 
                           (dsm.SALT.isel(Z=kk) 
                            * xr.ones_like(pres.isel(Z=slice(None,kk+1)))), 
                           (dsm.THETA.isel(Z=kk) 
                            * xr.ones_like(pres.isel(Z=slice(None,kk+1)))), 
                           pres.isel(Z=slice(None,kk+1)),
                           dask='parallelized')
    bt = (-alpha * grav/rhoConst)
    bs = (- beta * grav/rhoConst)
    Ht[dict(Z=kk)] = (bt * dsg.drF
                     ).reset_coords(drop=True
                                   ).sum('Z',skipna=True).chunk({'YC':ychunk,'XC':xchunk})
    Hs[dict(Z=kk)] = (bs * dsg.drF
                     ).reset_coords(drop=True
                                   ).sum('Z',skipna=True).chunk({'YC':ychunk,'XC':xchunk})
    
Tp = (ds.THETA - dsm.THETA).where(ds.maskC!=0.).reset_coords(drop=True)
Sp = (ds.SALT  -  dsm.SALT).where(ds.maskC!=0.).reset_coords(drop=True)
    
wp = ds.WVEL.reset_coords(drop=True) - dsm.WVEL
vp = ds.VVEL.reset_coords(drop=True) - dsm.VVEL
up = ds.UVEL.reset_coords(drop=True) - dsm.UVEL
    
xA = (ds.dyG * ds.drF * ds.hFacW).reset_coords(drop=True)
yA = (ds.dxG * ds.drF * ds.hFacS).reset_coords(drop=True)

upTrans = up * xA
vpTrans = vp * yA
rpTrans = wp * ds.rA
Autp = (upTrans
        * grid.interp(Tp,'X')
       )
Avtp = (vpTrans
        * grid.interp(Tp,'Y',boundary='extend')
       )
Awtp = (rpTrans
        * grid.interp(Tp * ds.hFacC,'Z',boundary='extend')
       )
    
Gt = ((grid.diff(Autp,'X')
       + grid.diff(Avtp,'Y',boundary='extend')
       - grid.diff(Awtp,'Z',boundary='extend')
      ) / ds.drF/ds.rA/ds.hFacC
     ).where(ds.maskC!=0.).reset_coords(drop=True)
    
Ausp = (upTrans
        * grid.interp(Sp,'X')
       )
Avsp = (vpTrans
        * grid.interp(Sp,'Y',boundary='extend')
       )
Awsp = (rpTrans
        * grid.interp(Sp * ds.hFacC,'Z',boundary='extend')
       )
    
Gs = ((grid.diff(Ausp,'X')
       + grid.diff(Avsp,'Y',boundary='extend')
       - grid.diff(Awsp,'Z',boundary='extend')
      ) / ds.drF/ds.rA/ds.hFacC
     ).where(ds.maskC!=0.).reset_coords(drop=True)
    
gradH = ((Ht * Gt.mean('time',skipna=True))
         + (Hs * Gs.mean('time',skipna=True))
        )
    
dsave = gradH.chunk({'YC':ychunk,'XC':xchunk}).to_dataset(name='H_')
print(dsave)
dsave.to_zarr(op.join(savedir,'%4d/Time-decomp/GradH.zarr' 
                          % (years[yystart])), mode='w')
dsave.close()
dsm.close()
ds.close()
del Gt, Gs, gradH
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-17352' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17353' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17354' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17355' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17356' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17357' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17358' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17359' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17360' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17361' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17362' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17363' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17364' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17365' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17366' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17367' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17368' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17369' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17370' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17371' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17372' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17373' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17374' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17375' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17376' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17377' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17378' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17379' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17380' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17381' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17382' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17383' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17384' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17385' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17386' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17387' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17388' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17389' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17390' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17391' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17392' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17393' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17394' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17395' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17396' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17397' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17398' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17399' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17400' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17401' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17402' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17403' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17404' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17405' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17406' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17407' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17408' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17409' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17410' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17411' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17412' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17413' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17414' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17415' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17416' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17417' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17418' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17419' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17420' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17421' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17422' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17423' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17424' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17425' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17426' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17427' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17428' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17429' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17430' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17431' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17432' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17433' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17434' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17435' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17436' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17437' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17438' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17439' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17440' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17441' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17442' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17443' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17444' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17445' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17446' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17447' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17448' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17449' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17450' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17451' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17452' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17453' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17454' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17455' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17456' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17457' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17458' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17459' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17460' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17461' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-17462' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# ...
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19391' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19392' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19393' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19394' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19395' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19396' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19397' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19398' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19399' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19400' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19401' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19402' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19403' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19404' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19405' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19406' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19407' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19408' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19409' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19410' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19411' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19412' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19413' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19414' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19415' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19416' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19417' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19418' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19419' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19420' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19421' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19422' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19423' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19424' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19425' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# Task exception was never retrieved
# future: <Task finished name='Task-19426' coro=<Client._gather.<locals>.wait() done, defined at /tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py:2119> exception=AllExit()>
# Traceback (most recent call last):
#   File "/tank/spectre/tuchida/envs/spec/lib/python3.9/site-packages/distributed/client.py", line 2128, in wait
#     raise AllExit()
# distributed.client.AllExit
# <xarray.Dataset>
# Dimensions:  (XC: 1000, YC: 900, Z: 46)
# Coordinates:
#   * XC       (XC) >f4 262.0 262.1 262.2 262.3 262.3 ... 347.7 347.8 347.9 348.0
#   * YC       (YC) >f4 -19.92 -19.83 -19.75 -19.67 ... 54.75 54.83 54.92 55.0
#   * Z        (Z) >f4 -3.047 -9.454 -16.36 ... -5.375e+03 -5.625e+03 -5.875e+03
# Data variables:
#     H_       (Z, YC, XC) float32 dask.array<chunksize=(46, 100, 100), meta=np.ndarray>

# %%
ymax = 43
ymin = 14
xmin = 270
xmax = 337

gH = xr.open_zarr(op.join(savedir,'%4d/Time-decomp/GradH.zarr' 
                                  % (years[yystart]))
                         ).H_.reset_coords(drop=True)
        
((gH*Vol).sel(
            Z=slice(None,-1e3),YC=slice(ymin,ymax),
            XC=slice(xmin,xmax)
            ).sum(['Z','YC','XC'],skipna=True)
 / Vol.sel(
           Z=slice(None,-1e3),YC=slice(ymin,ymax),
           XC=slice(xmin,xmax)
          ).sum(['Z','YC','XC'],skipna=True)
).compute()
# Out:
# <xarray.DataArray ()>
# array(3.5725698e-09, dtype=float32)
